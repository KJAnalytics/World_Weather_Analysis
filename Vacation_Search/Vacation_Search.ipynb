# %% [markdown]
# # Deliverable 2. Create a Customer Travel Destinations Map.
# ----
# 1. Create a folder called `Vacation_Search` to save all the files related with this deliverable.
#
# 2. Download the `Vacation_Search_starter_code.ipynb` Jupyter notebook,save it into your `Vacation_Search folder`, and rename it as `Vacation_Search.ipynb`.
#
# 3. In the `Vacation_Search.ipynb` file, ensure that the dependencies and the Google API key is imported correctly.
#
# 4. From the `Weather_Database` folder you created in the "Deliverable 1," import the `WeatherPy_Database.csv` file as a Pandas DataFrame named `city_data_df`.
#
# 5. Write two input statements that prompt the user to enter their minimum and maximum temperature criteria for their vacation.
#
# 6. Create a new Pandas DataFrame by using the `loc` Pandas method to filter the `city_data_df` DataFrame for temperature criteria  collected. Name the DataFrame as `preferred_cities_df`.
#
# 7. Create a new Pandas DataFrame named `clean_travel_cities` by using the Pandas `dropna` function on the `preferred_cities_df` to drop any empty rows.
#
# 8. Use the `copy` Pandas function to create a new DataFrame, called `hotel_df`, by copying the following columns from the `clean_travel_cities` DataFrame: "City", "Country", "Max Temp", "Current Description", "Lat", "Lng".
#
# 9. Add a new empty column named `Hotel Name` to the `hotel_df` DataFrame.
#
# 10. Review the hotel search parameters provided. These parameters are the same we used in this module; you'll use them to search for a hotel for each city.
#
# 11. Use a for loop to iterate through the `hotel_df` DataFrame, retrieve the latitude and longitude of each city to find the nearest hotel based on the search parameters provided, then add the hotel name to the `hotel_df` DataFrame. If a hotel isn't found, skip to the next city.
#
# 12. Drop any rows in the `hotel_df` DataFrame where a hotel name is not found and store the resulting data into a new DataFrame named `clean_hotel_df`.
#
# 13. Create an CSV file to store the `clean_hotel_df` DataFrame as `WeatherPy_vacation.csv` in the Vacation_Search folder.
#
# 14. Review the formatting template provided that you'll use to add an information box to each marker in the map. In the pop-up for each city you'll add:
#
#     1. The city name.
#
#     2. The country code.
#
#     3. The weather description and maximum temperature for the city.
#
# 15. Review the provided list comprehension code to retrieve the city data from each row, which will then be added to the formatting template and saved in the `hotel_info` list.
#
# 16. Use the provided code snippet to retrieve the latitude and longitude from each row and store them in a new DataFrame called `locations`.
#
# 17. Refactor your previous marker layer map code to create a marker layer map that will have pop-up markers for each city on the map.
#
# 18. Take a screenshot of your map and save it to the `Vacation_Search` folder as `WeatherPy_vacation_map.png`.
# ---

# %% [markdown]
# ## Ensure that the dependencies and the Google API key is imported correctly.

# %%
# Dependencies and Setup
import pandas as pd
import requests
import gmaps

# Import Google API key
from config import g_key

# Configure gmaps
gmaps.configure(api_key=g_key)

# %% [markdown]
# ## From the `Weather_Database` folder you created in the "Deliverable 1," import the `WeatherPy_Database.csv` file as a Pandas DataFrame.

# %%
# Set the file path to import the WeatherPy_database.csv file
# 1. Import the WeatherPy_database.csv file. 
city_data_df = pd.read_csv("Weather_Database/WeatherPy_database.csv")
city_data_df.head()
# Out:
#    City_ID      City Country      Lat       Lng  Max Temp  Humidity  \
# 0        0    Harper      LR   4.3750   -7.7169     75.51        89
# 1        1   Rikitea      PF -23.1203 -134.9692     70.29        70
# 2        2  Necochea      AR -38.5473  -58.7368     46.60        84
# 3        3  Coruripe      BR -10.1256  -36.1756     74.41        88
# 4        4   Ushuaia      AR -54.8000  -68.3000     42.46        70
#
#    Cloudiness  Wind Speed Current Description
# 0          98        5.70          light rain
# 1          14       23.35          few clouds
# 2           1        5.14           clear sky
# 3          13        8.34          few clouds
# 4          75        4.61       broken clouds

# %% [markdown]
# ## Write two input statements that prompt the user to enter their minimum and maximum temperature criteria for their vacation.

# %%
# Prompt the user to enter the minimum temperature criteria
min_temp = float(input("What is the minimum temperature you would like for your trip?"))


# Prompt the user to enter the maximum temperature criteria
max_temp = float(input("What is the maximum temperature you would like for your trip?"))
# Out:
# What is the minimum temperature you would like for your trip?55
# What is the maximum temperature you would like for your trip?80

# %% [markdown]
# ## Create a new Pandas DataFrame by using the `loc` Pandas method to filter the `city_data_df` DataFrame for temperature criteria  collected.

# %%
# Filter the city_data_df DataFrame to find the cities that fit the criteria using the loc Pandas function
preferred_cities_df = city_data_df.loc[(city_data_df["Max Temp"] <= max_temp) & (city_data_df["Max Temp"] >= min_temp)]
preferred_cities_df.head(10)
# Out:
#     City_ID                  City Country      Lat       Lng  Max Temp  \
# 0         0                Harper      LR   4.3750   -7.7169     75.51
# 1         1               Rikitea      PF -23.1203 -134.9692     70.29
# 3         3              Coruripe      BR -10.1256  -36.1756     74.41
# 5         5               Sahawar      IN  27.8000   78.8500     72.50
# 6         6          Port Augusta      AU -32.5000  137.7667     69.71
# 8         8             Busselton      AU -33.6500  115.3333     59.25
# 9         9                Castro      BR -24.7911  -50.0119     62.64
# 10       10               Mayumba      GA  -3.4320   10.6554     75.40
# 16       16       Arraial Do Cabo      BR -22.9661  -42.0278     71.15
# 18       18  Vila Franca Do Campo      PT  37.7167  -25.4333     67.19
#
#     Humidity  Cloudiness  Wind Speed Current Description
# 0         89          98        5.70          light rain
# 1         70          14       23.35          few clouds
# 3         88          13        8.34          few clouds
# 5         93         100        9.55     overcast clouds
# 6         30           0        9.44           clear sky
# 8         55          72        6.38       broken clouds
# 9         97         100        9.01          light rain
# 10        85         100        0.74          light rain
# 16        94          98       26.78          light rain
# 18        85          40        4.32    scattered clouds

# %% [markdown]
# ## Create a new Pandas DataFrame named `clean_travel_cities` by using the Pandas `dropna` function on the `preferred_cities_df` to drop any empty rows.

# %%
# 4a. Determine if there are any empty rows.
preferred_cities_df.count()
# Out:
# City_ID                360
# City                   360
# Country                357
# Lat                    360
# Lng                    360
# Max Temp               360
# Humidity               360
# Cloudiness             360
# Wind Speed             360
# Current Description    360
# dtype: int64

# %%
# 4b. Drop any empty rows and create a new DataFrame that doesn’t have empty rows.
clean_df = preferred_cities_df.dropna()
clean_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 357 entries, 0 to 712
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   City_ID              357 non-null    int64
#  1   City                 357 non-null    object
#  2   Country              357 non-null    object
#  3   Lat                  357 non-null    float64
#  4   Lng                  357 non-null    float64
#  5   Max Temp             357 non-null    float64
#  6   Humidity             357 non-null    int64
#  7   Cloudiness           357 non-null    int64
#  8   Wind Speed           357 non-null    float64
#  9   Current Description  357 non-null    object
# dtypes: float64(4), int64(3), object(3)
# memory usage: 30.7+ KB

# %% [markdown]
# ## Use the `copy` Pandas function to create a new DataFrame, called `hotel_df`, by copying the following columns from the `clean_travel_cities` DataFrame: "City", "Country", "Max Temp", "Current Description", "Lat", "Lng".

# %%
# Create DataFrame called hotel_df by copying some columns from the clean_travel_cities DataFrame.

hotel_df = clean_df[["City", "Country", "Max Temp", "Current Description", "Lat", "Lng"]].copy()

# %% [markdown]
# ## Add a new empty column named `Hotel Name` to the `hotel_df` DataFrame.

# %%
#  Create a new column "Hotel Name"
hotel_df["Hotel Name"] = ""
hotel_df.head(10)
# Out:
#                     City Country  Max Temp Current Description      Lat  \
# 0                 Harper      LR     75.51          light rain   4.3750
# 1                Rikitea      PF     70.29          few clouds -23.1203
# 3               Coruripe      BR     74.41          few clouds -10.1256
# 5                Sahawar      IN     72.50     overcast clouds  27.8000
# 6           Port Augusta      AU     69.71           clear sky -32.5000
# 8              Busselton      AU     59.25       broken clouds -33.6500
# 9                 Castro      BR     62.64          light rain -24.7911
# 10               Mayumba      GA     75.40          light rain  -3.4320
# 16       Arraial Do Cabo      BR     71.15          light rain -22.9661
# 18  Vila Franca Do Campo      PT     67.19    scattered clouds  37.7167
#
#          Lng Hotel Name
# 0    -7.7169
# 1  -134.9692
# 3   -36.1756
# 5    78.8500
# 6   137.7667
# 8   115.3333
# 9   -50.0119
# 10   10.6554
# 16  -42.0278
# 18  -25.4333

# %% [markdown]
# ## Review the hotel search parameters provided. These parameters are the same we used in this module; you'll use them to search for a hotel for each city.

# %%
# Review the parameters to search for a hotel
params = {
    "radius": 5000,
    "type": "lodging",
    "key": g_key
}

# %% [markdown]
# ## Use a for loop to iterate through the `hotel_df` DataFrame, retrieve the latitude and longitude of each city to find the nearest hotel based on the search parameters provided, then add the hotel name to the `hotel_df` DataFrame. If a hotel isn't found, skip to the next city.

# %%
# Iterate through the hotel DataFrame 
for index, row in hotel_df.iterrows():
    # Fetch latitude and longitude from the DataFrame
    lat = row["Lat"]
    lng = row["Lng"]

    
    # Add the latitude and longitude as parameters to the params dictionary
    params["location"] = f"{lat},{lng}"
    
    # Set up the base URL for the Google Directions API to get JSON data
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

    # Make an API request and retrieve the JSON data from the hotel search
    hotels = requests.get(base_url, params=params).json()
    
    # Get the first hotel from the results and store the name, if a hotel isn't found skip the city
    try:
        hotel_df.loc[index, "Hotel Name"] = hotels["results"][0]["name"]
    except (IndexError):
        print("Hotel not found... skipping.")
# Out:
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.

# %% [markdown]
# ## Drop any rows in the `hotel_df` DataFrame where a hotel name is not found and store the resulting data into a new DataFrame named `clean_hotel_df`.

# %%
 

# Drop the rows where there is no Hotel Name.

clean_hotel_df = hotel_df.dropna(subset=['Hotel Name'])
clean_hotel_df
# Out:
#               City Country  Max Temp Current Description      Lat       Lng  \
# 0           Harper      LR     75.51          light rain   4.3750   -7.7169
# 1          Rikitea      PF     70.29          few clouds -23.1203 -134.9692
# 3         Coruripe      BR     74.41          few clouds -10.1256  -36.1756
# 5          Sahawar      IN     72.50     overcast clouds  27.8000   78.8500
# 6     Port Augusta      AU     69.71           clear sky -32.5000  137.7667
# ..             ...     ...       ...                 ...      ...       ...
# 708  Alta Floresta      BR     75.29    scattered clouds  -9.8756  -56.0861
# 709            Vao      NC     71.11       broken clouds -22.6667  167.4833
# 710       Zorritos      PE     69.21    scattered clouds  -3.6805  -80.6782
# 711       Griffith      US     55.35     overcast clouds  41.5284  -87.4237
# 712    Gornoye Loo      RU     56.98           clear sky  43.7129   39.6049
#
#                       Hotel Name
# 0                    Screensaver
# 1                People ThankYou
# 3    Pousada e Hotel Litoral Sul
# 5                      कलुआ नगला
# 6      Majestic Oasis Apartments
# ..                           ...
# 708     Floresta Amazonica Hotel
# 709              Hotel Kou-Bugny
# 710                Hotel Pinamar
# 711    Apartment above Depot Bar
# 712         «ВатерЛоо» гостиница
#
# [357 rows x 7 columns]

# %% [markdown]
# ## Create an CSV file to store the `clean_hotel_df` DataFrame as `WeatherPy_vacation.csv` in the Vacation_Search folder.

# %%
# Set the file name.
output_data_file = "Vacation_Search/WeatherPy_vacation.csv"
# 8b. Export the City_Data into a csv
clean_hotel_df.to_csv(output_data_file, index_label="City_ID")

# %% [markdown]
# ### Review the formatting template provided that you'll use to add an information box to each marker in the map.
#
# In the pop-up for each city you'll add:
#
# 1. The city name
#
# 2. The country code
#
# 3. The weather description and maximum temperature for the city

# %%
# Configure gmaps
gmaps.configure(api_key=g_key)

# Review the formatting template provided
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Current Weather</dt><dd>{Current Description} 
<dt>CMax Temp</dt><dd>{Max Temp} °F</dd>
</dl>
"""

# %% [markdown]
# ## Review the provided list comprehension code to retrieve the city data from each row, which will then be added to the formatting template and saved in the `hotel_info` list.

# %%
# Get the data from each row in the clean_hotel_df DataFrame, add it to the formatting template, and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in clean_hotel_df.iterrows()]

# Display sample data
hotel_info
# Out:
# ['\n<dl>\n<dt>Hotel Name</dt><dd>Screensaver</dd>\n<dt>City</dt><dd>Harper</dd>\n<dt>Country</dt><dd>LR</dd>\n<dt>Current Weather</dt><dd>light rain \n<dt>CMax Temp</dt><dd>75.51 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>People ThankYou</dd>\n<dt>City</dt><dd>Rikitea</dd>\n<dt>Country</dt><dd>PF</dd>\n<dt>Current Weather</dt><dd>few clouds \n<dt>CMax Temp</dt><dd>70.29 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Pousada e Hotel Litoral Sul</dd>\n<dt>City</dt><dd>Coruripe</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Current Weather</dt><dd>few clouds \n<dt>CMax Temp</dt><dd>74.41 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>कलुआ नगला</dd>\n<dt>City</dt><dd>Sahawar</dd>\n<dt>Country</dt><dd>IN</dd>\n<dt>Current Weather</dt><dd>overcast clouds \n<dt>CMax Temp</dt><dd>72.5 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Majestic Oasis Apartments</dd>\n<dt>City</dt><dd>Port Augusta</dd>\n<dt>Country</dt><dd>AU</dd>\n<dt>Current Weather</dt><dd>clear sky \n<dt>CMax Temp</dt><dd>69.71 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Observatory Guest House</dd>\n<dt>City</dt><dd>Busselton</dd>\n<dt>Country</dt><dd>AU</dd>\n<dt>Current Weather</dt><dd>broken clouds \n<dt>CMax Temp</dt><dd>59.25 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>CHACARA BAILLY</dd>\n<dt>City</dt><dd>Castro</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Current Weather</dt><dd>light rain \n<dt>CMax Temp</dt><dd>62.64 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>LIKWALE LODGE</dd>\n<dt>City</dt><dd>Mayumba</dd>\n<dt>Country</dt><dd>GA</dd>\n<dt>Current Weather</dt><dd>light rain \n<dt>CMax Temp</dt><dd>75.4 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Pousada Porto Praia</dd>\n<dt>City</dt><dd>Arraial Do Cabo</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Current Weather</dt><dd>light rain \n<dt>CMax Temp</dt><dd>71.15 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Pestana Bahia Praia</dd>\n<dt>City</dt><dd>Vila Franca Do Campo</dd>\n<dt>Country</dt><dd>PT</dd>\n<dt>Current Weather</dt><dd>scattered clouds \n<dt>CMax Temp</dt><dd>67.19 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Embassy Suites by Hilton Huntsville</dd>\n<dt>City</dt><dd>Huntsville</dd>\n<dt>Country</dt><dd>US</dd>\n<dt>Current Weather</dt><dd>clear sky \n<dt>CMax Temp</dt><dd>62.11 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hospitality Carnarvon</dd>\n<dt>City</dt><dd>Carnarvon</dd>\n<dt>Country</dt><dd>AU</dd>\n<dt>Current Weather</dt><dd>clear sky \n<dt>CMax Temp</dt><dd>72.21 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Casa Tia Villa</dd>\n<dt>City</dt><dd>Bambous Virieux</dd>\n<dt>Country</dt><dd>MU</dd>\n<dt>Current Weather</dt><dd>few clouds \n<dt>CMax Temp</dt><dd>74.21 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Alamdar Hotel</dd>\n<dt>City</dt><dd>Bafq</dd>\n<dt>Country</dt><dd>IR</dd>\n<dt>Current Weather</dt><dd>clear sky \n<dt>CMax Temp</dt><dd>71.53 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd></dd>\n<dt>City</dt><dd>Albany</dd>\n<dt>Country</dt><dd>US</dd>\n<dt>Current Weather</dt><dd>overcast clouds \n<dt>CMax Temp</dt><dd>57.88 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>HAMDAN PLAZA HOTEL SALALAH, an HTG Hotel</dd>\n<dt>City</dt><dd>Salalah</dd>\n<dt>Country</dt><dd>OM</dd>\n<dt>Current Weather</dt><dd>broken clouds \n<dt>CMax Temp</dt><dd>78.89 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>The Halyards Hotel</dd>\n<dt>City</dt><dd>Port Alfred</dd>\n<dt>Country</dt><dd>ZA</dd>\n<dt>Current Weather</dt><dd>overcast clouds \n<dt>CMax Temp</dt><dd>57.18 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Courtyard by Marriott Harlingen</dd>\n<dt>City</dt><dd>Harlingen</dd>\n<dt>Country</dt><dd>US</dd>\n<dt>Current Weather</dt><dd>clear sky \n<dt>CMax Temp</dt><dd>78.71 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Kanjirowa</dd>\n<dt>City</dt><dd>Dhankuta</dd>\n<dt>Country</dt><dd>NP</dd>\n<dt>Current Weather</dt><dd>few clouds \n<dt>CMax Temp</dt><dd>73.08 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Shanti Maurice Resort & Spa</dd>\n<dt>City</dt><dd>Souillac</dd>\n<dt>Country</dt><dd>MU</dd>\n<dt>Current Weather</dt><dd>few clouds \n<dt>CMax Temp</dt><dd>73.78 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Port Lincoln Hotel</dd>\n<dt>City</dt><dd>Port Lincoln</dd>\n<dt>Country</dt><dd>AU</dd>\n<dt>Current Weather</dt><dd>overcast clouds \n<dt>CMax Temp</dt><dd>57.06 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Le four à pain</dd>\n<dt>City</dt><dd>Saint-Philippe</dd>\n<dt>Country</dt><dd>RE</dd>\n<dt>Current Weather</dt><dd>scattered clouds \n<dt>CMax Temp</dt><dd>72.99 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>حيد القفلة</dd>\n<dt>City</dt><dd>Marzuq</dd>\n<dt>Country</dt><dd>YE</dd>\n<dt>Current Weather</dt><dd>overcast clouds \n<dt>CMax Temp</dt><dd>75.99 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Westmark Sitka</dd>\n<dt>City</dt><dd>Sitka</dd>\n<dt>Country</dt><dd>US</dd>\n<dt>Current Weather</dt><dd>scattered clouds \n<dt>CMax Temp</dt><dd>57.09 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Finch Bay Galapagos Hotel</dd>\n<dt>City</dt><dd>Puerto Ayora</dd>\n<dt>Country</dt><dd>EC</dd>\n<dt>Current Weather</dt><dd>broken clouds \n<dt>CMax Temp</dt><dd>65.55 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Grage Hotel Bengkulu</dd>\n<dt>City</dt><dd>Bengkulu</dd>\n<dt>Country</dt><dd>ID</dd>\n<dt>Current Weather</dt><dd>overcast clouds \n<dt>CMax Temp</dt><dd>76.01 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Villa Enata</dd>\n<dt>City</dt><dd>Atuona</dd>\n<dt>Country</dt><dd>PF</dd>\n<dt>Current Weather</dt><dd>clear sky \n<dt>CMax Temp</dt><dd>77.54 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd></dd>\n<dt>City</dt><dd>Camacupa</dd>\n<dt>Country</dt><dd>AO</dd>\n<dt>Current Weather</dt><dd>broken clouds \n<dt>CMax Temp</dt><dd>61.66 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Ahipara Holiday Park</dd>\n<dt>City</dt><dd>Ahipara</dd>\n<dt>Country</dt><dd>NZ</dd>\n<dt>Current Weather</dt><dd>broken clouds \n<dt>CMax Temp</dt><dd>56.5 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Shandrani Beachcomber Resort & Spa</dd>\n<dt>City</dt><dd>Mahebourg</dd>\n<dt>Country</dt><dd>MU</dd>\n<dt>Current Weather</dt><dd>few clouds \n<dt>CMax Temp</dt><dd>74.25 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Best Western Plus Abbey Inn</dd>\n<dt>City</dt><dd>Saint George</dd>\n<dt>Country</dt><dd>US</dd>\n<dt>Current Weather</dt><dd>clear sky \n<dt>CMax Temp</dt><dd>78.26 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Gran Lençóis Flat Residence</dd>\n<dt>City</dt><dd>Barreirinhas</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Current Weather</dt><dd>broken clouds \n<dt>CMax Temp</dt><dd>77.81 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Do Terço</dd>\n<dt>City</dt><dd>Barcelos</dd>\n<dt>Country</dt><dd>PT</dd>\n<dt>Current Weather</dt><dd>clear sky \n<dt>CMax Temp</dt><dd>67.91 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Falang Government Guesthouse</dd>\n<dt>City</dt><dd>Falam</dd>\n<dt>Country</dt><dd>MM</dd>\n<dt>Current Weather</dt><dd>few clouds \n<dt>CMax Temp</dt><dd>76.66 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hampton Inn & Suites Jamestown</dd>\n<dt>City</dt><dd>Jamestown</dd>\n<dt>Country</dt><dd>US</dd>\n<dt>Current Weather</dt><dd>overcast clouds \n<dt>CMax Temp</dt><dd>60.71 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Broadwater Mariner Resort</dd>\n<dt>City</dt><dd>Geraldton</dd>\n<dt>Country</dt><dd>AU</dd>\n<dt>Current Weather</dt><dd>clear sky \n<dt>CMax Temp</dt><dd>70.21 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Eureka Inn Trademark By Wyndham</dd>\n<dt>City</dt><dd>Eureka</dd>\n<dt>Country</dt><dd>US</dd>\n<dt>Current Weather</dt><dd>overcast clouds \n<dt>CMax Temp</dt><dd>59.67 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hôtel Le Dronmi</dd>\n<dt>City</dt><dd>Cayenne</dd>\n<dt>Country</dt><dd>GF</dd>\n<dt>Current Weather</dt><dd>clear sky \n<dt>CMax Temp</dt><dd>73.44 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>شيلة نسايم</dd>\n<dt>City</dt><dd>Faya</dd>\n<dt>Country</dt><dd>SA</dd>\n<dt>Current Weather</dt><dd>overcast clouds \n<dt>CMax Temp</dt><dd>64.92 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>The Esplanade Resort & Spa</dd>\n<dt>City</dt><dd>Lakes Entrance</dd>\n<dt>Country</dt><dd>AU</dd>\n<dt>Current Weather</dt><dd>moderate rain \n<dt>CMax Temp</dt><dd>68.16 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Business Hotel ASTRUM Laus</dd>\n<dt>City</dt><dd>Leua</dd>\n<dt>Country</dt><dd>SK</dd>\n<dt>Current Weather</dt><dd>scattered clouds \n<dt>CMax Temp</dt><dd>55.49 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Olako</dd>\n<dt>City</dt><dd>Omboue</dd>\n<dt>Country</dt><dd>GA</dd>\n<dt>Current Weather</dt><dd>overcast clouds \n<dt>CMax Temp</dt><dd>75.6 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>St Ives Hobart Accommodation Tasmania</dd>\n<dt>City</dt><dd>Hobart</dd>\n<dt>Country</dt><dd>AU</dd>\n<dt>Current Weather</dt><dd>broken clouds \n<dt>CMax Temp</dt><dd>66.06 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hôtel Abda</dd>\n<dt>City</dt><dd>Asfi</dd>\n<dt>Country</dt><dd>MA</dd>\n<dt>Current Weather</dt><dd>broken clouds \n<dt>CMax Temp</dt><dd>70.7 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Lakan Hotel</dd>\n<dt>City</dt><dd>Tonj</dd>\n<dt>Country</dt><dd>SS</dd>\n<dt>Current Weather</dt><dd>few clouds \n<dt>CMax Temp</dt><dd>69.55 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Tu Casa</dd>\n<dt>City</dt><dd>East London</dd>\n<dt>Country</dt><dd>ZA</dd>\n<dt>Current Weather</dt><dd>few clouds \n<dt>CMax Temp</dt><dd>61.74 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Suites Las Palmas</dd>\n<dt>City</dt><dd>Ojinaga</dd>\n<dt>Country</dt><dd>MX</dd>\n<dt>Current Weather</dt><dd>clear sky \n<dt>CMax Temp</dt><dd>70.75 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Radisson Blu Hotel Waterfront, Cape Town</dd>\n<dt>City</dt><dd>Cape Town</dd>\n<dt>Country</dt><dd>ZA</dd>\n<dt>Current Weather</dt><dd>few clouds \n<dt>CMax Temp</dt><dd>58.37 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Codrington Gardens Bed And Breakfast</dd>\n<dt>City</dt><dd>Codrington</dd>\n<dt>Country</dt><dd>AU</dd>\n<dt>Current Weather</dt><dd>scattered clouds \n<dt>CMax Temp</dt><dd>59.49 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Courtyard by Marriott Danbury</dd>\n<dt>City</dt><dd>Bethel</dd>\n<dt>Country</dt><dd>US</dd>\n<dt>Current Weather</dt><dd>clear sky \n<dt>CMax Temp</dt><dd>59.14 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>El Medina</dd>\n<dt>City</dt><dd>Nouadhibou</dd>\n<dt>Country</dt><dd>MR</dd>\n<dt>Current Weather</dt><dd>sand \n<dt>CMax Temp</dt><dd>73.38 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Malibu Country Inn</dd>\n<dt>City</dt><dd>Malibu</dd>\n<dt>Country</dt><dd>US</dd>\n<dt>Current Weather</dt><dd>broken clouds \n<dt>CMax Temp</dt><dd>70.84 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Shingu UI Hotel</dd>\n<dt>City</dt><dd>Shingu</dd>\n<dt>Country</dt><dd>JP</dd>\n<dt>Current Weather</dt><dd>overcast clouds \n<dt>CMax Temp</dt><dd>69.15 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Casa Maquia</dd>\n<dt>City</dt><dd>Lata</dd>\n<dt>Country</dt><dd>PT</dd>\n<dt>Current Weather</dt><dd>broken clouds \n<dt>CMax Temp</dt><dd>55.08 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>The Shingles Riverside Cottages</dd>\n<dt>City</dt><dd>New Norfolk</dd>\n<dt>Country</dt><dd>AU</dd>\n<dt>Current Weather</dt><dd>light rain \n<dt>CMax Temp</dt><dd>66.92 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hospitality Esperance</dd>\n<dt>City</dt><dd>Esperance</dd>\n<dt>Country</dt><dd>AU</dd>\n<dt>Current Weather</dt><dd>overcast clouds \n<dt>CMax Temp</dt><dd>57.56 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Foyer ADM</dd>\n<dt>City</dt><dd>Mitsamiouli</dd>\n<dt>Country</dt><dd>KM</dd>\n<dt>Current Weather</dt><dd>clear sky \n<dt>CMax Temp</dt><dd>76.53 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>حامد محمد نور</dd>\n<dt>City</dt><dd>Abu Zabad</dd>\n<dt>Country</dt><dd>SD</dd>\n<dt>Current Weather</dt><dd>overcast clouds \n<dt>CMax Temp</dt><dd>75.38 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Nuevo Hotel Plaza</dd>\n<dt>City</dt><dd>Chuy</dd>\n<dt>Country</dt><dd>UY</dd>\n<dt>Current Weather</dt><dd>overcast clouds \n<dt>CMax Temp</dt><dd>55.8 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Angsoka Hotel Teluk Intan</dd>\n<dt>City</dt><dd>Teluk Intan</dd>\n<dt>Country</dt><dd>MY</dd>\n<dt>Current Weather</dt><dd>overcast clouds \n<dt>CMax Temp</dt><dd>77.02 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Complexe</dd>\n<dt>City</dt><dd>Maine-Soroa</dd>\n<dt>Country</dt><dd>NE</dd>\n<dt>Current Weather</dt><dd>overcast clouds \n<dt>CMax Temp</dt><dd>78.91 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Santa Carmem</dd>\n<dt>City</dt><dd>Pitanga</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Current Weather</dt><dd>overcast clouds \n<dt>CMax Temp</dt><dd>62.06 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Kareespruit Game Ranch and Guest House</dd>\n<dt>City</dt><dd>Zeerust</dd>\n<dt>Country</dt><dd>ZA</dd>\n<dt>Current Weather</dt><dd>clear sky \n<dt>CMax Temp</dt><dd>62.64 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Piaçabuçu News</dd>\n<dt>City</dt><dd>Piacabucu</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Current Weather</dt><dd>clear sky \n<dt>CMax Temp</dt><dd>74.91 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Meirujia Hotel</dd>\n<dt>City</dt><dd>Tongliao</dd>\n<dt>Country</dt><dd>CN</dd>\n<dt>Current Weather</dt><dd>few clouds \n<dt>CMax Temp</dt><dd>59.5 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Fiesta Inn Monclova</dd>\n<dt>City</dt><dd>Frontera</dd>\n<dt>Country</dt><dd>MX</dd>\n<dt>Current Weather</dt><dd>overcast clouds \n<dt>CMax Temp</dt><dd>68.32 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Dali Travelling With Hostel</dd>\n<dt>City</dt><dd>Dali</dd>\n<dt>Country</dt><dd>CN</dd>\n<dt>Current Weather</dt><dd>broken clouds \n<dt>CMax Temp</dt><dd>69.04 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Bora-Bora Pearl Beach Resort & Spa</dd>\n<dt>City</dt><dd>Faanui</dd>\n<dt>Country</dt><dd>PF</dd>\n<dt>Current Weather</dt><dd>light rain \n<dt>CMax Temp</dt><dd>78.3 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd></dd>\n<dt>City</dt><dd>Yangambi</dd>\n<dt>Country</dt><dd>CD</dd>\n<dt>Current Weather</dt><dd>light rain \n<dt>CMax Temp</dt><dd>68.68 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Country Lodge Solwezi</dd>\n<dt>City</dt><dd>Solwezi</dd>\n<dt>Country</dt><dd>ZM</dd>\n<dt>Current Weather</dt><dd>broken clouds \n<dt>CMax Temp</dt><dd>58.33 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hôtel Restaurant Gourmand Coco Lodge Majunga</dd>\n<dt>City</dt><dd>Mahajanga</dd>\n<dt>Country</dt><dd>MG</dd>\n<dt>Current Weather</dt><dd>clear sky \n<dt>CMax Temp</dt><dd>75.22 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>OYO 170 Hotel View Point</dd>\n<dt>City</dt><dd>Pokhara</dd>\n<dt>Country</dt><dd>NP</dd>\n<dt>Current Weather</dt><dd>overcast clouds \n<dt>CMax Temp</dt><dd>78.39 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Solares Hotel</dd>\n<dt>City</dt><dd>Pinheiro</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Current Weather</dt><dd>clear sky \n<dt>CMax Temp</dt><dd>71.85 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Obelisco</dd>\n<dt>City</dt><dd>Cobija</dd>\n<dt>Country</dt><dd>BO</dd>\n<dt>Current Weather</dt><dd>broken clouds \n<dt>CMax Temp</dt><dd>73.27 °F</dd>\n</dl>\n',
#  "\n<dl>\n<dt>Hotel Name</dt><dd>Big Red's</dd>\n<dt>City</dt><dd>Bull Savanna</dd>\n<dt>Country</dt><dd>JM</dd>\n<dt>Current Weather</dt><dd>overcast clouds \n<dt>CMax Temp</dt><dd>76.96 °F</dd>\n</dl>\n",
#  '\n<dl>\n<dt>Hotel Name</dt><dd>محمد هادي ال فطيح</dd>\n<dt>City</dt><dd>Najran</dd>\n<dt>Country</dt><dd>SA</dd>\n<dt>Current Weather</dt><dd>overcast clouds \n<dt>CMax Temp</dt><dd>74.05 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Ted McQuinn Trust</dd>\n<dt>City</dt><dd>Bud</dd>\n<dt>Country</dt><dd>US</dd>\n<dt>Current Weather</dt><dd>clear sky \n<dt>CMax Temp</dt><dd>62.58 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>DEPARTAMENTOS LA ESTANCIA</dd>\n<dt>City</dt><dd>Puerto Madero</dd>\n<dt>Country</dt><dd>MX</dd>\n<dt>Current Weather</dt><dd>scattered clouds \n<dt>CMax Temp</dt><dd>75.4 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Fengshui Residence</dd>\n<dt>City</dt><dd>Port-Gentil</dd>\n<dt>Country</dt><dd>GA</dd>\n<dt>Current Weather</dt><dd>overcast clouds \n<dt>CMax Temp</dt><dd>77.67 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>The Sebel Kiama Harbourside</dd>\n<dt>City</dt><dd>Kiama</dd>\n<dt>Country</dt><dd>AU</dd>\n<dt>Current Weather</dt><dd>light rain \n<dt>CMax Temp</dt><dd>69.39 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Shellharbour Resort & Conference Centre</dd>\n<dt>City</dt><dd>Flinders</dd>\n<dt>Country</dt><dd>AU</dd>\n<dt>Current Weather</dt><dd>light rain \n<dt>CMax Temp</dt><dd>69.19 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Embassy Suites by Hilton Portland Downtown</dd>\n<dt>City</dt><dd>Portland</dd>\n<dt>Country</dt><dd>US</dd>\n<dt>Current Weather</dt><dd>few clouds \n<dt>CMax Temp</dt><dd>69.24 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>The George</dd>\n<dt>City</dt><dd>Christchurch</dd>\n<dt>Country</dt><dd>NZ</dd>\n<dt>Current Weather</dt><dd>clear sky \n<dt>CMax Temp</dt><dd>56.32 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Backpackers Inn</dd>\n<dt>City</dt><dd>Byron Bay</dd>\n<dt>Country</dt><dd>AU</dd>\n<dt>Current Weather</dt><dd>broken clouds \n<dt>CMax Temp</dt><dd>71.94 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Sitima Inn</dd>\n<dt>City</dt><dd>Nkhotakota</dd>\n<dt>Country</dt><dd>MW</dd>\n<dt>Current Weather</dt><dd>clear sky \n<dt>CMax Temp</dt><dd>71.33 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Lidera</dd>\n<dt>City</dt><dd>Carutapera</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Current Weather</dt><dd>few clouds \n<dt>CMax Temp</dt><dd>77.56 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Quinta da Meia Eira</dd>\n<dt>City</dt><dd>Ribeira Grande</dd>\n<dt>Country</dt><dd>PT</dd>\n<dt>Current Weather</dt><dd>overcast clouds \n<dt>CMax Temp</dt><dd>71.38 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Paradise Inn</dd>\n<dt>City</dt><dd>Avarua</dd>\n<dt>Country</dt><dd>CK</dd>\n<dt>Current Weather</dt><dd>few clouds \n<dt>CMax Temp</dt><dd>77.05 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Branco I</dd>\n<dt>City</dt><dd>Praia Da Vitoria</dd>\n<dt>Country</dt><dd>PT</dd>\n<dt>Current Weather</dt><dd>light intensity shower rain \n<dt>CMax Temp</dt><dd>69.76 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Amethyst Court Motor lodge (Best Price on direct bookings)</dd>\n<dt>City</dt><dd>Porirua</dd>\n<dt>Country</dt><dd>NZ</dd>\n<dt>Current Weather</dt><dd>clear sky \n<dt>CMax Temp</dt><dd>55.54 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Landmark</dd>\n<dt>City</dt><dd>Ratnagiri</dd>\n<dt>Country</dt><dd>IN</dd>\n<dt>Current Weather</dt><dd>moderate rain \n<dt>CMax Temp</dt><dd>76.51 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Gulisitan Hotel</dd>\n<dt>City</dt><dd>Korla</dd>\n<dt>Country</dt><dd>CN</dd>\n<dt>Current Weather</dt><dd>broken clouds \n<dt>CMax Temp</dt><dd>62.08 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Castelo</dd>\n<dt>City</dt><dd>Cidreira</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Current Weather</dt><dd>moderate rain \n<dt>CMax Temp</dt><dd>63.68 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Taloa Heights</dd>\n<dt>City</dt><dd>Alofi</dd>\n<dt>Country</dt><dd>NU</dd>\n<dt>Current Weather</dt><dd>broken clouds \n<dt>CMax Temp</dt><dd>76.89 °F</dd>\n</dl>\n',
#  "\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Yuliana's</dd>\n<dt>City</dt><dd>Tibu</dd>\n<dt>Country</dt><dd>CO</dd>\n<dt>Current Weather</dt><dd>overcast clouds \n<dt>CMax Temp</dt><dd>72.55 °F</dd>\n</dl>\n",
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Garden Hotel</dd>\n<dt>City</dt><dd>Jingdezhen</dd>\n<dt>Country</dt><dd>CN</dd>\n<dt>Current Weather</dt><dd>overcast clouds \n<dt>CMax Temp</dt><dd>57.36 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>EYL AQUE SYSTEM</dd>\n<dt>City</dt><dd>Eyl</dd>\n<dt>Country</dt><dd>SO</dd>\n<dt>Current Weather</dt><dd>broken clouds \n<dt>CMax Temp</dt><dd>79.21 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Holiday Inn Express Lompoc, an IHG Hotel</dd>\n<dt>City</dt><dd>Lompoc</dd>\n<dt>Country</dt><dd>US</dd>\n<dt>Current Weather</dt><dd>fog \n<dt>CMax Temp</dt><dd>59.52 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Shishime Hotel</dd>\n<dt>City</dt><dd>Naze</dd>\n<dt>Country</dt><dd>JP</dd>\n<dt>Current Weather</dt><dd>overcast clouds \n<dt>CMax Temp</dt><dd>76.12 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel do Campo</dd>\n<dt>City</dt><dd>Ponta Do Sol</dd>\n<dt>Country</dt><dd>PT</dd>\n<dt>Current Weather</dt><dd>scattered clouds \n<dt>CMax Temp</dt><dd>72.23 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Super 8 by Wyndham Fortuna</dd>\n<dt>City</dt><dd>Fortuna</dd>\n<dt>Country</dt><dd>US</dd>\n<dt>Current Weather</dt><dd>overcast clouds \n<dt>CMax Temp</dt><dd>56.35 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>guarderia imss papalote</dd>\n<dt>City</dt><dd>Socorro</dd>\n<dt>Country</dt><dd>US</dd>\n<dt>Current Weather</dt><dd>broken clouds \n<dt>CMax Temp</dt><dd>67.21 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Springfields Hotel</dd>\n<dt>City</dt><dd>Horsham</dd>\n<dt>Country</dt><dd>GB</dd>\n<dt>Current Weather</dt><dd>broken clouds \n<dt>CMax Temp</dt><dd>58.44 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Sahel Hotel</dd>\n<dt>City</dt><dd>Yagoua</dd>\n<dt>Country</dt><dd>CM</dd>\n<dt>Current Weather</dt><dd>overcast clouds \n<dt>CMax Temp</dt><dd>72.72 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd></dd>\n<dt>City</dt><dd>Poum</dd>\n<dt>Country</dt><dd>NC</dd>\n<dt>Current Weather</dt><dd>clear sky \n<dt>CMax Temp</dt><dd>75.99 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Villa de las Palmas</dd>\n<dt>City</dt><dd>Purificacion</dd>\n<dt>Country</dt><dd>CO</dd>\n<dt>Current Weather</dt><dd>broken clouds \n<dt>CMax Temp</dt><dd>74.12 °F</dd>\n</dl>\n',
#  "\n<dl>\n<dt>Hotel Name</dt><dd>Hôtel de l'UCom CVPC</dd>\n<dt>City</dt><dd>Banikoara</dd>\n<dt>Country</dt><dd>BJ</dd>\n<dt>Current Weather</dt><dd>overcast clouds \n<dt>CMax Temp</dt><dd>72.37 °F</dd>\n</dl>\n",
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Festival Plaza Rosarito</dd>\n<dt>City</dt><dd>Rosarito</dd>\n<dt>Country</dt><dd>MX</dd>\n<dt>Current Weather</dt><dd>scattered clouds \n<dt>CMax Temp</dt><dd>66.47 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Dongfang Hotel</dd>\n<dt>City</dt><dd>Pingdu</dd>\n<dt>Country</dt><dd>CN</dd>\n<dt>Current Weather</dt><dd>clear sky \n<dt>CMax Temp</dt><dd>61.83 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>GreenTree Alliance Laibin Railway Station Hotel</dd>\n<dt>City</dt><dd>Laibin</dd>\n<dt>Country</dt><dd>CN</dd>\n<dt>Current Weather</dt><dd>broken clouds \n<dt>CMax Temp</dt><dd>75.15 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Aldea del Bazar Hotel and Spa</dd>\n<dt>City</dt><dd>Puerto Escondido</dd>\n<dt>Country</dt><dd>MX</dd>\n<dt>Current Weather</dt><dd>clear sky \n<dt>CMax Temp</dt><dd>79.21 °F</dd>\n</dl>\n',
#  "\n<dl>\n<dt>Hotel Name</dt><dd>HOTEL D'ASSISE</dd>\n<dt>City</dt><dd>Mossendjo</dd>\n<dt>Country</dt><dd>CG</dd>\n<dt>Current Weather</dt><dd>moderate rain \n<dt>CMax Temp</dt><dd>69.17 °F</dd>\n</dl>\n",
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Motherland Guesthouse</dd>\n<dt>City</dt><dd>Thaba-Tseka</dd>\n<dt>Country</dt><dd>LS</dd>\n<dt>Current Weather</dt><dd>broken clouds \n<dt>CMax Temp</dt><dd>56.12 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Beachfront Voyager Motor Inn</dd>\n<dt>City</dt><dd>Burnie</dd>\n<dt>Country</dt><dd>AU</dd>\n<dt>Current Weather</dt><dd>overcast clouds \n<dt>CMax Temp</dt><dd>57.94 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Ngari Hill Ecolodge</dd>\n<dt>City</dt><dd>Maralal</dd>\n<dt>Country</dt><dd>KE</dd>\n<dt>Current Weather</dt><dd>scattered clouds \n<dt>CMax Temp</dt><dd>57.78 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Halane Hotel and Restaurent</dd>\n<dt>City</dt><dd>Hobyo</dd>\n<dt>Country</dt><dd>SO</dd>\n<dt>Current Weather</dt><dd>broken clouds \n<dt>CMax Temp</dt><dd>78.01 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Ramada Limited Indianapolis West</dd>\n<dt>City</dt><dd>Speedway</dd>\n<dt>Country</dt><dd>US</dd>\n<dt>Current Weather</dt><dd>scattered clouds \n<dt>CMax Temp</dt><dd>62.8 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Apartamentos Castelli 90</dd>\n<dt>City</dt><dd>Santiago Del Estero</dd>\n<dt>Country</dt><dd>AR</dd>\n<dt>Current Weather</dt><dd>clear sky \n<dt>CMax Temp</dt><dd>63.19 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Katsuura Hotel Mikazuki</dd>\n<dt>City</dt><dd>Katsuura</dd>\n<dt>Country</dt><dd>JP</dd>\n<dt>Current Weather</dt><dd>light rain \n<dt>CMax Temp</dt><dd>59.02 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Residencial Eluzai</dd>\n<dt>City</dt><dd>Boyuibe</dd>\n<dt>Country</dt><dd>BO</dd>\n<dt>Current Weather</dt><dd>broken clouds \n<dt>CMax Temp</dt><dd>64.67 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Ikathouse</dd>\n<dt>City</dt><dd>Komsomolskiy</dd>\n<dt>Country</dt><dd>UZ</dd>\n<dt>Current Weather</dt><dd>overcast clouds \n<dt>CMax Temp</dt><dd>65.12 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>MacKenzie House Tourist Home B&B</dd>\n<dt>City</dt><dd>Port Hawkesbury</dd>\n<dt>Country</dt><dd>CA</dd>\n<dt>Current Weather</dt><dd>mist \n<dt>CMax Temp</dt><dd>57.18 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Green Valley</dd>\n<dt>City</dt><dd>Rosetta</dd>\n<dt>Country</dt><dd>EG</dd>\n<dt>Current Weather</dt><dd>clear sky \n<dt>CMax Temp</dt><dd>72.23 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Seigetsu Ryokan</dd>\n<dt>City</dt><dd>Aki</dd>\n<dt>Country</dt><dd>JP</dd>\n<dt>Current Weather</dt><dd>light rain \n<dt>CMax Temp</dt><dd>69.75 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd></dd>\n<dt>City</dt><dd>Rudbar</dd>\n<dt>Country</dt><dd>AF</dd>\n<dt>Current Weather</dt><dd>clear sky \n<dt>CMax Temp</dt><dd>65.98 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel BR 364</dd>\n<dt>City</dt><dd>Cacoal</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Current Weather</dt><dd>overcast clouds \n<dt>CMax Temp</dt><dd>78.57 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Coolum Beach Resort</dd>\n<dt>City</dt><dd>Coolum Beach</dd>\n<dt>Country</dt><dd>AU</dd>\n<dt>Current Weather</dt><dd>broken clouds \n<dt>CMax Temp</dt><dd>74.1 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Vitória Palace</dd>\n<dt>City</dt><dd>Vila Velha</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Current Weather</dt><dd>scattered clouds \n<dt>CMax Temp</dt><dd>75.15 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd></dd>\n<dt>City</dt><dd>Sibut</dd>\n<dt>Country</dt><dd>CF</dd>\n<dt>Current Weather</dt><dd>moderate rain \n<dt>CMax Temp</dt><dd>67.73 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Desert Gardens Hotel - Ayers Rock Resort</dd>\n<dt>City</dt><dd>Yulara</dd>\n<dt>Country</dt><dd>AU</dd>\n<dt>Current Weather</dt><dd>clear sky \n<dt>CMax Temp</dt><dd>77.38 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel de Ville</dd>\n<dt>City</dt><dd>Antsohihy</dd>\n<dt>Country</dt><dd>MG</dd>\n<dt>Current Weather</dt><dd>clear sky \n<dt>CMax Temp</dt><dd>74.95 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Cuenca</dd>\n<dt>City</dt><dd>Cuenca</dd>\n<dt>Country</dt><dd>EC</dd>\n<dt>Current Weather</dt><dd>overcast clouds \n<dt>CMax Temp</dt><dd>55.53 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Wedgewood Motel</dd>\n<dt>City</dt><dd>Palmer</dd>\n<dt>Country</dt><dd>US</dd>\n<dt>Current Weather</dt><dd>clear sky \n<dt>CMax Temp</dt><dd>59.18 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd></dd>\n<dt>City</dt><dd>San Benito</dd>\n<dt>Country</dt><dd>US</dd>\n<dt>Current Weather</dt><dd>broken clouds \n<dt>CMax Temp</dt><dd>60.85 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Xaguate</dd>\n<dt>City</dt><dd>Sao Filipe</dd>\n<dt>Country</dt><dd>CV</dd>\n<dt>Current Weather</dt><dd>broken clouds \n<dt>CMax Temp</dt><dd>78.69 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Pacifica Lighthouse, Trademark Collection by Wyndham</dd>\n<dt>City</dt><dd>Pacifica</dd>\n<dt>Country</dt><dd>US</dd>\n<dt>Current Weather</dt><dd>mist \n<dt>CMax Temp</dt><dd>67.42 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Nacala Plaza Business Design Hotel</dd>\n<dt>City</dt><dd>Nacala</dd>\n<dt>Country</dt><dd>MZ</dd>\n<dt>Current Weather</dt><dd>clear sky \n<dt>CMax Temp</dt><dd>73.83 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>"Plantation Bed and Breakfast</dd>\n<dt>City</dt><dd>Saint-Joseph</dd>\n<dt>Country</dt><dd>RE</dd>\n<dt>Current Weather</dt><dd>few clouds \n<dt>CMax Temp</dt><dd>73.78 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Porto Santo & Spa</dd>\n<dt>City</dt><dd>Camacha</dd>\n<dt>Country</dt><dd>PT</dd>\n<dt>Current Weather</dt><dd>few clouds \n<dt>CMax Temp</dt><dd>67.42 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Villa Kitzia Huacho</dd>\n<dt>City</dt><dd>Hualmay</dd>\n<dt>Country</dt><dd>PE</dd>\n<dt>Current Weather</dt><dd>clear sky \n<dt>CMax Temp</dt><dd>60.73 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Casona del General</dd>\n<dt>City</dt><dd>Ciudad Del Maiz</dd>\n<dt>Country</dt><dd>MX</dd>\n<dt>Current Weather</dt><dd>overcast clouds \n<dt>CMax Temp</dt><dd>61.11 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Palácio da Lousã</dd>\n<dt>City</dt><dd>Lousa</dd>\n<dt>Country</dt><dd>PT</dd>\n<dt>Current Weather</dt><dd>broken clouds \n<dt>CMax Temp</dt><dd>65.07 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Ginga</dd>\n<dt>City</dt><dd>Malanje</dd>\n<dt>Country</dt><dd>AO</dd>\n<dt>Current Weather</dt><dd>overcast clouds \n<dt>CMax Temp</dt><dd>64.63 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd></dd>\n<dt>City</dt><dd>Maridi</dd>\n<dt>Country</dt><dd>SS</dd>\n<dt>Current Weather</dt><dd>overcast clouds \n<dt>CMax Temp</dt><dd>65.66 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Fangyuan Hotel</dd>\n<dt>City</dt><dd>Jiaojiang</dd>\n<dt>Country</dt><dd>CN</dd>\n<dt>Current Weather</dt><dd>overcast clouds \n<dt>CMax Temp</dt><dd>66.99 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Al Djadid</dd>\n<dt>City</dt><dd>Domoni</dd>\n<dt>Country</dt><dd>KM</dd>\n<dt>Current Weather</dt><dd>light rain \n<dt>CMax Temp</dt><dd>76.28 °F</dd>\n</dl>\n',
#  "\n<dl>\n<dt>Hotel Name</dt><dd>Motel de l'UNITE</dd>\n<dt>City</dt><dd>Bouar</dd>\n<dt>Country</dt><dd>CF</dd>\n<dt>Current Weather</dt><dd>overcast clouds \n<dt>CMax Temp</dt><dd>63.36 °F</dd>\n</dl>\n",
#  '\n<dl>\n<dt>Hotel Name</dt><dd></dd>\n<dt>City</dt><dd>Beloha</dd>\n<dt>Country</dt><dd>MG</dd>\n<dt>Current Weather</dt><dd>clear sky \n<dt>CMax Temp</dt><dd>77.81 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>New Century Hotel</dd>\n<dt>City</dt><dd>Xingcheng</dd>\n<dt>Country</dt><dd>CN</dd>\n<dt>Current Weather</dt><dd>clear sky \n<dt>CMax Temp</dt><dd>58.84 °F</dd>\n</dl>\n',
#  "\n<dl>\n<dt>Hotel Name</dt><dd>Pousada Guará's</dd>\n<dt>City</dt><dd>Tutoia</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Current Weather</dt><dd>few clouds \n<dt>CMax Temp</dt><dd>78.85 °F</dd>\n</dl>\n",
#  '\n<dl>\n<dt>Hotel Name</dt><dd>El rranchito michuacan de ocampos</dd>\n<dt>City</dt><dd>Coahuayana</dd>\n<dt>Country</dt><dd>MX</dd>\n<dt>Current Weather</dt><dd>overcast clouds \n<dt>CMax Temp</dt><dd>76.17 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Aipana Plaza Hotel</dd>\n<dt>City</dt><dd>Boa Vista</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Current Weather</dt><dd>few clouds \n<dt>CMax Temp</dt><dd>78.78 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Herdeiros de Antunes Capusso</dd>\n<dt>City</dt><dd>Kuito</dd>\n<dt>Country</dt><dd>AO</dd>\n<dt>Current Weather</dt><dd>overcast clouds \n<dt>CMax Temp</dt><dd>57.72 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>39 On Nile Guest House</dd>\n<dt>City</dt><dd>Port Elizabeth</dd>\n<dt>Country</dt><dd>ZA</dd>\n<dt>Current Weather</dt><dd>clear sky \n<dt>CMax Temp</dt><dd>59.31 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Puerto del Sol</dd>\n<dt>City</dt><dd>Pimentel</dd>\n<dt>Country</dt><dd>PE</dd>\n<dt>Current Weather</dt><dd>scattered clouds \n<dt>CMax Temp</dt><dd>61.52 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd></dd>\n<dt>City</dt><dd>San Mateo Del Mar</dd>\n<dt>Country</dt><dd>MX</dd>\n<dt>Current Weather</dt><dd>broken clouds \n<dt>CMax Temp</dt><dd>79.57 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Madona Guest House Kaabong</dd>\n<dt>City</dt><dd>Kaabong</dd>\n<dt>Country</dt><dd>UG</dd>\n<dt>Current Weather</dt><dd>broken clouds \n<dt>CMax Temp</dt><dd>66.0 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Veranda Paul et Virginie Hotel & Spa</dd>\n<dt>City</dt><dd>Grand Gaube</dd>\n<dt>Country</dt><dd>MU</dd>\n<dt>Current Weather</dt><dd>few clouds \n<dt>CMax Temp</dt><dd>74.37 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>المنزل</dd>\n<dt>City</dt><dd>Awjilah</dd>\n<dt>Country</dt><dd>LY</dd>\n<dt>Current Weather</dt><dd>clear sky \n<dt>CMax Temp</dt><dd>64.9 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Oryx Palace</dd>\n<dt>City</dt><dd>Bongor</dd>\n<dt>Country</dt><dd>TD</dd>\n<dt>Current Weather</dt><dd>overcast clouds \n<dt>CMax Temp</dt><dd>72.36 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hostal Zapata</dd>\n<dt>City</dt><dd>Adra</dd>\n<dt>Country</dt><dd>ES</dd>\n<dt>Current Weather</dt><dd>clear sky \n<dt>CMax Temp</dt><dd>63.37 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Pousada dos Navegantes</dd>\n<dt>City</dt><dd>Caravelas</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Current Weather</dt><dd>overcast clouds \n<dt>CMax Temp</dt><dd>74.39 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Qinhuangdao Peninsula Seasons Hotel And Apartment</dd>\n<dt>City</dt><dd>Qinhuangdao</dd>\n<dt>Country</dt><dd>CN</dd>\n<dt>Current Weather</dt><dd>clear sky \n<dt>CMax Temp</dt><dd>63.72 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Oustaz Vame DIAKITE</dd>\n<dt>City</dt><dd>Odienne</dd>\n<dt>Country</dt><dd>CI</dd>\n<dt>Current Weather</dt><dd>broken clouds \n<dt>CMax Temp</dt><dd>70.16 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Riviera Royal Hotel</dd>\n<dt>City</dt><dd>Conakry</dd>\n<dt>Country</dt><dd>GN</dd>\n<dt>Current Weather</dt><dd>scattered clouds \n<dt>CMax Temp</dt><dd>78.62 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Six Acres Bed & Breakfast</dd>\n<dt>City</dt><dd>Hamilton</dd>\n<dt>Country</dt><dd>US</dd>\n<dt>Current Weather</dt><dd>few clouds \n<dt>CMax Temp</dt><dd>60.44 °F</dd>\n</dl>\n',
#  "\n<dl>\n<dt>Hotel Name</dt><dd>Marriott's Ko Olina Beach Club</dd>\n<dt>City</dt><dd>Makakilo City</dd>\n<dt>Country</dt><dd>US</dd>\n<dt>Current Weather</dt><dd>scattered clouds \n<dt>CMax Temp</dt><dd>79.12 °F</dd>\n</dl>\n",
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Formule 11 Accomodation</dd>\n<dt>City</dt><dd>Frankfort</dd>\n<dt>Country</dt><dd>ZA</dd>\n<dt>Current Weather</dt><dd>clear sky \n<dt>CMax Temp</dt><dd>63.1 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Italian pasley</dd>\n<dt>City</dt><dd>Sakaiminato</dd>\n<dt>Country</dt><dd>JP</dd>\n<dt>Current Weather</dt><dd>broken clouds \n<dt>CMax Temp</dt><dd>66.18 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Best Western Solhem Hotel Visby</dd>\n<dt>City</dt><dd>Visby</dd>\n<dt>Country</dt><dd>SE</dd>\n<dt>Current Weather</dt><dd>clear sky \n<dt>CMax Temp</dt><dd>55.62 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd></dd>\n<dt>City</dt><dd>Albacete</dd>\n<dt>Country</dt><dd>ES</dd>\n<dt>Current Weather</dt><dd>scattered clouds \n<dt>CMax Temp</dt><dd>57.18 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Laoyutang Resort</dd>\n<dt>City</dt><dd>Hami</dd>\n<dt>Country</dt><dd>CN</dd>\n<dt>Current Weather</dt><dd>clear sky \n<dt>CMax Temp</dt><dd>62.15 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Abroma Hotel</dd>\n<dt>City</dt><dd>Mojo</dd>\n<dt>Country</dt><dd>ET</dd>\n<dt>Current Weather</dt><dd>broken clouds \n<dt>CMax Temp</dt><dd>58.48 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Castilla</dd>\n<dt>City</dt><dd>Las Lomas</dd>\n<dt>Country</dt><dd>PA</dd>\n<dt>Current Weather</dt><dd>overcast clouds \n<dt>CMax Temp</dt><dd>75.79 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Galvarino</dd>\n<dt>City</dt><dd>Tocopilla</dd>\n<dt>Country</dt><dd>CL</dd>\n<dt>Current Weather</dt><dd>few clouds \n<dt>CMax Temp</dt><dd>62.47 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd></dd>\n<dt>City</dt><dd>Airai</dd>\n<dt>Country</dt><dd>TL</dd>\n<dt>Current Weather</dt><dd>scattered clouds \n<dt>CMax Temp</dt><dd>78.01 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>美吉屋旅館</dd>\n<dt>City</dt><dd>Tanabe</dd>\n<dt>Country</dt><dd>JP</dd>\n<dt>Current Weather</dt><dd>broken clouds \n<dt>CMax Temp</dt><dd>67.21 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Resorts Resource Group International</dd>\n<dt>City</dt><dd>Mayo</dd>\n<dt>Country</dt><dd>US</dd>\n<dt>Current Weather</dt><dd>clear sky \n<dt>CMax Temp</dt><dd>62.94 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>The Grace Sydney</dd>\n<dt>City</dt><dd>Sydney</dd>\n<dt>Country</dt><dd>AU</dd>\n<dt>Current Weather</dt><dd>light intensity drizzle \n<dt>CMax Temp</dt><dd>67.35 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Legacy Vacation Resorts - Brigantine Beach</dd>\n<dt>City</dt><dd>Brigantine</dd>\n<dt>Country</dt><dd>US</dd>\n<dt>Current Weather</dt><dd>clear sky \n<dt>CMax Temp</dt><dd>61.02 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>La Bodeguita Pousada</dd>\n<dt>City</dt><dd>Mucuri</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Current Weather</dt><dd>overcast clouds \n<dt>CMax Temp</dt><dd>74.23 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Macs</dd>\n<dt>City</dt><dd>Russell</dd>\n<dt>Country</dt><dd>US</dd>\n<dt>Current Weather</dt><dd>clear sky \n<dt>CMax Temp</dt><dd>60.4 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Chase Country Inn Motel</dd>\n<dt>City</dt><dd>Chase</dd>\n<dt>Country</dt><dd>CA</dd>\n<dt>Current Weather</dt><dd>overcast clouds \n<dt>CMax Temp</dt><dd>60.33 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>GreenTree Hotel Rongcheng Bus Station</dd>\n<dt>City</dt><dd>Yatou</dd>\n<dt>Country</dt><dd>CN</dd>\n<dt>Current Weather</dt><dd>clear sky \n<dt>CMax Temp</dt><dd>62.51 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel San Juan</dd>\n<dt>City</dt><dd>Coquimbo</dd>\n<dt>Country</dt><dd>CL</dd>\n<dt>Current Weather</dt><dd>clear sky \n<dt>CMax Temp</dt><dd>56.93 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Toyoko-Inn Izumoshi ekimae</dd>\n<dt>City</dt><dd>Izumo</dd>\n<dt>Country</dt><dd>JP</dd>\n<dt>Current Weather</dt><dd>broken clouds \n<dt>CMax Temp</dt><dd>66.15 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Sea Lounge! Bar, Club & Restaurant</dd>\n<dt>City</dt><dd>Itarema</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Current Weather</dt><dd>clear sky \n<dt>CMax Temp</dt><dd>77.63 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Fuente del Guania Hotel de Lujo</dd>\n<dt>City</dt><dd>Inirida</dd>\n<dt>Country</dt><dd>CO</dd>\n<dt>Current Weather</dt><dd>overcast clouds \n<dt>CMax Temp</dt><dd>76.48 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Kost Pria</dd>\n<dt>City</dt><dd>Meulaboh</dd>\n<dt>Country</dt><dd>ID</dd>\n<dt>Current Weather</dt><dd>heavy intensity rain \n<dt>CMax Temp</dt><dd>74.41 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Kaianã</dd>\n<dt>City</dt><dd>Lagoa Vermelha</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Current Weather</dt><dd>overcast clouds \n<dt>CMax Temp</dt><dd>58.91 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>The Times Premier Lodge</dd>\n<dt>City</dt><dd>Vryburg</dd>\n<dt>Country</dt><dd>ZA</dd>\n<dt>Current Weather</dt><dd>broken clouds \n<dt>CMax Temp</dt><dd>57.47 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Alejandro I</dd>\n<dt>City</dt><dd>Salta</dd>\n<dt>Country</dt><dd>AR</dd>\n<dt>Current Weather</dt><dd>clear sky \n<dt>CMax Temp</dt><dd>56.57 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Balihai Bungalows</dd>\n<dt>City</dt><dd>Chicama</dd>\n<dt>Country</dt><dd>PE</dd>\n<dt>Current Weather</dt><dd>scattered clouds \n<dt>CMax Temp</dt><dd>57.74 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Rasa Residential Hotel</dd>\n<dt>City</dt><dd>Ramsar</dd>\n<dt>Country</dt><dd>IR</dd>\n<dt>Current Weather</dt><dd>broken clouds \n<dt>CMax Temp</dt><dd>69.24 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Axim Beach Resort And Spa</dd>\n<dt>City</dt><dd>Axim</dd>\n<dt>Country</dt><dd>GH</dd>\n<dt>Current Weather</dt><dd>light rain \n<dt>CMax Temp</dt><dd>75.0 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Arrarte</dd>\n<dt>City</dt><dd>Rocha</dd>\n<dt>Country</dt><dd>UY</dd>\n<dt>Current Weather</dt><dd>overcast clouds \n<dt>CMax Temp</dt><dd>55.78 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Citra</dd>\n<dt>City</dt><dd>Sabang</dd>\n<dt>Country</dt><dd>ID</dd>\n<dt>Current Weather</dt><dd>light rain \n<dt>CMax Temp</dt><dd>78.57 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd></dd>\n<dt>City</dt><dd>Nioro</dd>\n<dt>Country</dt><dd>GM</dd>\n<dt>Current Weather</dt><dd>clear sky \n<dt>CMax Temp</dt><dd>75.13 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Praia Hotel Imbituba</dd>\n<dt>City</dt><dd>Imbituba</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Current Weather</dt><dd>overcast clouds \n<dt>CMax Temp</dt><dd>68.86 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Oya Hotel</dd>\n<dt>City</dt><dd>Gelibolu</dd>\n<dt>Country</dt><dd>TR</dd>\n<dt>Current Weather</dt><dd>scattered clouds \n<dt>CMax Temp</dt><dd>60.66 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel da Amazônia</dd>\n<dt>City</dt><dd>Borba</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Current Weather</dt><dd>broken clouds \n<dt>CMax Temp</dt><dd>79.61 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Abha Hotel</dd>\n<dt>City</dt><dd>Abha</dd>\n<dt>Country</dt><dd>SA</dd>\n<dt>Current Weather</dt><dd>clear sky \n<dt>CMax Temp</dt><dd>64.65 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Charvid</dd>\n<dt>City</dt><dd>Lokoja</dd>\n<dt>Country</dt><dd>NG</dd>\n<dt>Current Weather</dt><dd>light rain \n<dt>CMax Temp</dt><dd>72.45 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel San Rafael</dd>\n<dt>City</dt><dd>San Rafael</dd>\n<dt>Country</dt><dd>AR</dd>\n<dt>Current Weather</dt><dd>scattered clouds \n<dt>CMax Temp</dt><dd>60.98 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Days Inn by Wyndham Duncan</dd>\n<dt>City</dt><dd>Duncan</dd>\n<dt>Country</dt><dd>US</dd>\n<dt>Current Weather</dt><dd>clear sky \n<dt>CMax Temp</dt><dd>68.22 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Pousada Camboinha</dd>\n<dt>City</dt><dd>Cabedelo</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Current Weather</dt><dd>scattered clouds \n<dt>CMax Temp</dt><dd>75.87 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Lolelunga Forest Reserve</dd>\n<dt>City</dt><dd>Kasempa</dd>\n<dt>Country</dt><dd>ZM</dd>\n<dt>Current Weather</dt><dd>scattered clouds \n<dt>CMax Temp</dt><dd>68.11 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd></dd>\n<dt>City</dt><dd>Pompeu</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Current Weather</dt><dd>overcast clouds \n<dt>CMax Temp</dt><dd>69.66 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Quality Inn Near Chico State</dd>\n<dt>City</dt><dd>Chico</dd>\n<dt>Country</dt><dd>US</dd>\n<dt>Current Weather</dt><dd>few clouds \n<dt>CMax Temp</dt><dd>77.67 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Delong Hotel</dd>\n<dt>City</dt><dd>Shache</dd>\n<dt>Country</dt><dd>CN</dd>\n<dt>Current Weather</dt><dd>broken clouds \n<dt>CMax Temp</dt><dd>62.26 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Casa Das Faias</dd>\n<dt>City</dt><dd>Lagoa</dd>\n<dt>Country</dt><dd>PT</dd>\n<dt>Current Weather</dt><dd>light rain \n<dt>CMax Temp</dt><dd>70.18 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Shimoda Tokyu Hotel</dd>\n<dt>City</dt><dd>Shimoda</dd>\n<dt>Country</dt><dd>JP</dd>\n<dt>Current Weather</dt><dd>overcast clouds \n<dt>CMax Temp</dt><dd>59.36 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Lovers Point Inn</dd>\n<dt>City</dt><dd>Pacific Grove</dd>\n<dt>Country</dt><dd>US</dd>\n<dt>Current Weather</dt><dd>overcast clouds \n<dt>CMax Temp</dt><dd>59.02 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Rio Xingu Camping</dd>\n<dt>City</dt><dd>Sao Felix Do Xingu</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Current Weather</dt><dd>broken clouds \n<dt>CMax Temp</dt><dd>77.09 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Maiombe</dd>\n<dt>City</dt><dd>Cabinda</dd>\n<dt>Country</dt><dd>AO</dd>\n<dt>Current Weather</dt><dd>light rain \n<dt>CMax Temp</dt><dd>75.27 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd></dd>\n<dt>City</dt><dd>Yaan</dd>\n<dt>Country</dt><dd>NG</dd>\n<dt>Current Weather</dt><dd>light rain \n<dt>CMax Temp</dt><dd>70.9 °F</dd>\n</dl>\n',
#  "\n<dl>\n<dt>Hotel Name</dt><dd>Don Eddie's Sport Fishing Center</dd>\n<dt>City</dt><dd>San Quintin</dd>\n<dt>Country</dt><dd>MX</dd>\n<dt>Current Weather</dt><dd>few clouds \n<dt>CMax Temp</dt><dd>67.96 °F</dd>\n</dl>\n",
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Matu Island</dd>\n<dt>City</dt><dd>Brokopondo</dd>\n<dt>Country</dt><dd>SR</dd>\n<dt>Current Weather</dt><dd>few clouds \n<dt>CMax Temp</dt><dd>76.59 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>La Quinta Inn & Suites by Wyndham Buena Park</dd>\n<dt>City</dt><dd>La Palma</dd>\n<dt>Country</dt><dd>US</dd>\n<dt>Current Weather</dt><dd>broken clouds \n<dt>CMax Temp</dt><dd>71.94 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Ruyi Hostel</dd>\n<dt>City</dt><dd>Wencheng</dd>\n<dt>Country</dt><dd>CN</dd>\n<dt>Current Weather</dt><dd>overcast clouds \n<dt>CMax Temp</dt><dd>57.97 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Guesthouse Nara Komachi</dd>\n<dt>City</dt><dd>Nara</dd>\n<dt>Country</dt><dd>JP</dd>\n<dt>Current Weather</dt><dd>light rain \n<dt>CMax Temp</dt><dd>62.49 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Sandpiper Motel</dd>\n<dt>City</dt><dd>Ulladulla</dd>\n<dt>Country</dt><dd>AU</dd>\n<dt>Current Weather</dt><dd>light rain \n<dt>CMax Temp</dt><dd>62.74 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd></dd>\n<dt>City</dt><dd>Tambacounda</dd>\n<dt>Country</dt><dd>SN</dd>\n<dt>Current Weather</dt><dd>light rain \n<dt>CMax Temp</dt><dd>75.78 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Vila Mineira | Oliveira MG</dd>\n<dt>City</dt><dd>Oliveira</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Current Weather</dt><dd>overcast clouds \n<dt>CMax Temp</dt><dd>64.54 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Vila Nova Hotel</dd>\n<dt>City</dt><dd>Ponta Delgada</dd>\n<dt>Country</dt><dd>PT</dd>\n<dt>Current Weather</dt><dd>few clouds \n<dt>CMax Temp</dt><dd>67.5 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel y Club de Golf Avándaro</dd>\n<dt>City</dt><dd>Valle De Bravo</dd>\n<dt>Country</dt><dd>MX</dd>\n<dt>Current Weather</dt><dd>overcast clouds \n<dt>CMax Temp</dt><dd>60.19 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Tianxiachan Hotel</dd>\n<dt>City</dt><dd>Huangmei</dd>\n<dt>Country</dt><dd>CN</dd>\n<dt>Current Weather</dt><dd>overcast clouds \n<dt>CMax Temp</dt><dd>57.2 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>OYO 884 Rumoh PMI Hotel</dd>\n<dt>City</dt><dd>Banda Aceh</dd>\n<dt>Country</dt><dd>ID</dd>\n<dt>Current Weather</dt><dd>overcast clouds \n<dt>CMax Temp</dt><dd>77.29 °F</dd>\n</dl>\n',
# ...
#  '\n<dl>\n<dt>Hotel Name</dt><dd>La maison des femmes prostituées ou Bourdelles de tenkodogo</dd>\n<dt>City</dt><dd>Koupela</dd>\n<dt>Country</dt><dd>BF</dd>\n<dt>Current Weather</dt><dd>overcast clouds \n<dt>CMax Temp</dt><dd>77.29 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>محمدالمبروك الاريقط</dd>\n<dt>City</dt><dd>Mizdah</dd>\n<dt>Country</dt><dd>LY</dd>\n<dt>Current Weather</dt><dd>clear sky \n<dt>CMax Temp</dt><dd>57.96 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Adouly Hôtel</dd>\n<dt>City</dt><dd>Saint-Raphael</dd>\n<dt>Country</dt><dd>HT</dd>\n<dt>Current Weather</dt><dd>overcast clouds \n<dt>CMax Temp</dt><dd>71.4 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Cortez Malaga Techy Caroly</dd>\n<dt>City</dt><dd>Iquitos</dd>\n<dt>Country</dt><dd>PE</dd>\n<dt>Current Weather</dt><dd>broken clouds \n<dt>CMax Temp</dt><dd>75.24 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Crôa Mares Hotel</dd>\n<dt>City</dt><dd>Sao Jose Da Coroa Grande</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Current Weather</dt><dd>few clouds \n<dt>CMax Temp</dt><dd>74.53 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Oota Ryokan</dd>\n<dt>City</dt><dd>Muroto</dd>\n<dt>Country</dt><dd>JP</dd>\n<dt>Current Weather</dt><dd>overcast clouds \n<dt>CMax Temp</dt><dd>73.49 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel los Algarrobos</dd>\n<dt>City</dt><dd>Puerto Baquerizo Moreno</dd>\n<dt>Country</dt><dd>EC</dd>\n<dt>Current Weather</dt><dd>scattered clouds \n<dt>CMax Temp</dt><dd>66.78 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Las Tirajanas</dd>\n<dt>City</dt><dd>Santa Lucia</dd>\n<dt>Country</dt><dd>ES</dd>\n<dt>Current Weather</dt><dd>few clouds \n<dt>CMax Temp</dt><dd>63.72 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Miramar</dd>\n<dt>City</dt><dd>Huarmey</dd>\n<dt>Country</dt><dd>PE</dd>\n<dt>Current Weather</dt><dd>clear sky \n<dt>CMax Temp</dt><dd>61.47 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Pousada Rua Camurupim</dd>\n<dt>City</dt><dd>Aquiraz</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Current Weather</dt><dd>scattered clouds \n<dt>CMax Temp</dt><dd>79.18 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Pousada Beija Flor</dd>\n<dt>City</dt><dd>Conde</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Current Weather</dt><dd>broken clouds \n<dt>CMax Temp</dt><dd>74.66 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Changyu Hotel</dd>\n<dt>City</dt><dd>Simao</dd>\n<dt>Country</dt><dd>CN</dd>\n<dt>Current Weather</dt><dd>few clouds \n<dt>CMax Temp</dt><dd>76.21 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Tateyama Seaside Hotel</dd>\n<dt>City</dt><dd>Tateyama</dd>\n<dt>Country</dt><dd>JP</dd>\n<dt>Current Weather</dt><dd>light rain \n<dt>CMax Temp</dt><dd>58.93 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Pousada Vista da Serra</dd>\n<dt>City</dt><dd>Ibicui</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Current Weather</dt><dd>overcast clouds \n<dt>CMax Temp</dt><dd>68.07 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Alarne - Área De Lazer Do Alto Rio Negro</dd>\n<dt>City</dt><dd>Sao Gabriel Da Cachoeira</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Current Weather</dt><dd>few clouds \n<dt>CMax Temp</dt><dd>75.29 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Juba</dd>\n<dt>City</dt><dd>Mogadishu</dd>\n<dt>Country</dt><dd>SO</dd>\n<dt>Current Weather</dt><dd>scattered clouds \n<dt>CMax Temp</dt><dd>78.67 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Stayable Select</dd>\n<dt>City</dt><dd>Gainesville</dd>\n<dt>Country</dt><dd>US</dd>\n<dt>Current Weather</dt><dd>clear sky \n<dt>CMax Temp</dt><dd>62.74 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hospedaje Eco</dd>\n<dt>City</dt><dd>Lagunas</dd>\n<dt>Country</dt><dd>PE</dd>\n<dt>Current Weather</dt><dd>moderate rain \n<dt>CMax Temp</dt><dd>79.75 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Tucupita Su\u200bite C.A.</dd>\n<dt>City</dt><dd>Tucupita</dd>\n<dt>Country</dt><dd>VE</dd>\n<dt>Current Weather</dt><dd>broken clouds \n<dt>CMax Temp</dt><dd>72.97 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>d.light malinyi Ec</dd>\n<dt>City</dt><dd>Malinyi</dd>\n<dt>Country</dt><dd>TZ</dd>\n<dt>Current Weather</dt><dd>clear sky \n<dt>CMax Temp</dt><dd>73.49 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Sun Rice Otel</dd>\n<dt>City</dt><dd>Erdemli</dd>\n<dt>Country</dt><dd>TR</dd>\n<dt>Current Weather</dt><dd>clear sky \n<dt>CMax Temp</dt><dd>72.14 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Salinas Park Resort Maçarico AP101</dd>\n<dt>City</dt><dd>Salinopolis</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Current Weather</dt><dd>scattered clouds \n<dt>CMax Temp</dt><dd>78.98 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hilton Garden Inn Qidong</dd>\n<dt>City</dt><dd>Huilong</dd>\n<dt>Country</dt><dd>CN</dd>\n<dt>Current Weather</dt><dd>overcast clouds \n<dt>CMax Temp</dt><dd>66.92 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Chik Chik Namibe</dd>\n<dt>City</dt><dd>Namibe</dd>\n<dt>Country</dt><dd>AO</dd>\n<dt>Current Weather</dt><dd>overcast clouds \n<dt>CMax Temp</dt><dd>63.28 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Embajador Villa Constitucion</dd>\n<dt>City</dt><dd>Villa Constitucion</dd>\n<dt>Country</dt><dd>AR</dd>\n<dt>Current Weather</dt><dd>clear sky \n<dt>CMax Temp</dt><dd>60.03 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Vitasoa</dd>\n<dt>City</dt><dd>Antalaha</dd>\n<dt>Country</dt><dd>MG</dd>\n<dt>Current Weather</dt><dd>scattered clouds \n<dt>CMax Temp</dt><dd>75.25 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hostal La Terraza</dd>\n<dt>City</dt><dd>Yaguajay</dd>\n<dt>Country</dt><dd>CU</dd>\n<dt>Current Weather</dt><dd>scattered clouds \n<dt>CMax Temp</dt><dd>77.4 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Lingot d’or</dd>\n<dt>City</dt><dd>Kati</dd>\n<dt>Country</dt><dd>ML</dd>\n<dt>Current Weather</dt><dd>overcast clouds \n<dt>CMax Temp</dt><dd>72.81 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Meridijan</dd>\n<dt>City</dt><dd>Pag</dd>\n<dt>Country</dt><dd>HR</dd>\n<dt>Current Weather</dt><dd>overcast clouds \n<dt>CMax Temp</dt><dd>55.98 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Divi Village Golf & Beach Resort</dd>\n<dt>City</dt><dd>Oranjestad</dd>\n<dt>Country</dt><dd>AW</dd>\n<dt>Current Weather</dt><dd>broken clouds \n<dt>CMax Temp</dt><dd>78.91 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Sofitel Algiers Hamma Garden</dd>\n<dt>City</dt><dd>Algiers</dd>\n<dt>Country</dt><dd>DZ</dd>\n<dt>Current Weather</dt><dd>light rain \n<dt>CMax Temp</dt><dd>73.22 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel California Todos Santos</dd>\n<dt>City</dt><dd>Todos Santos</dd>\n<dt>Country</dt><dd>MX</dd>\n<dt>Current Weather</dt><dd>clear sky \n<dt>CMax Temp</dt><dd>78.66 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Tour Eiffel Hotel Benin</dd>\n<dt>City</dt><dd>Porto Novo</dd>\n<dt>Country</dt><dd>BJ</dd>\n<dt>Current Weather</dt><dd>moderate rain \n<dt>CMax Temp</dt><dd>78.62 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>COMBUESA</dd>\n<dt>City</dt><dd>Ondjiva</dd>\n<dt>Country</dt><dd>AO</dd>\n<dt>Current Weather</dt><dd>broken clouds \n<dt>CMax Temp</dt><dd>67.98 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Posada Llovizna Rodríguez</dd>\n<dt>City</dt><dd>San Felipe</dd>\n<dt>Country</dt><dd>VE</dd>\n<dt>Current Weather</dt><dd>overcast clouds \n<dt>CMax Temp</dt><dd>70.07 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd></dd>\n<dt>City</dt><dd>Baoning</dd>\n<dt>Country</dt><dd>CN</dd>\n<dt>Current Weather</dt><dd>overcast clouds \n<dt>CMax Temp</dt><dd>66.06 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Star inn Peniche</dd>\n<dt>City</dt><dd>Peniche</dd>\n<dt>Country</dt><dd>PT</dd>\n<dt>Current Weather</dt><dd>clear sky \n<dt>CMax Temp</dt><dd>58.1 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Best Western Dry Creek Inn</dd>\n<dt>City</dt><dd>Healdsburg</dd>\n<dt>Country</dt><dd>US</dd>\n<dt>Current Weather</dt><dd>clear sky \n<dt>CMax Temp</dt><dd>73.9 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Tourist Lodge</dd>\n<dt>City</dt><dd>Basavakalyan</dd>\n<dt>Country</dt><dd>IN</dd>\n<dt>Current Weather</dt><dd>overcast clouds \n<dt>CMax Temp</dt><dd>70.9 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Tajiri Inn</dd>\n<dt>City</dt><dd>Kushikino</dd>\n<dt>Country</dt><dd>JP</dd>\n<dt>Current Weather</dt><dd>overcast clouds \n<dt>CMax Temp</dt><dd>69.26 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Sainik Hotel And Lodge</dd>\n<dt>City</dt><dd>Khandbari</dd>\n<dt>Country</dt><dd>NP</dd>\n<dt>Current Weather</dt><dd>scattered clouds \n<dt>CMax Temp</dt><dd>78.06 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Sankhani Guest House</dd>\n<dt>City</dt><dd>Chadiza</dd>\n<dt>Country</dt><dd>ZM</dd>\n<dt>Current Weather</dt><dd>clear sky \n<dt>CMax Temp</dt><dd>70.48 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd></dd>\n<dt>City</dt><dd>Fairfield</dd>\n<dt>Country</dt><dd>US</dd>\n<dt>Current Weather</dt><dd>clear sky \n<dt>CMax Temp</dt><dd>61.45 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hostal La Alameda</dd>\n<dt>City</dt><dd>Caraz</dd>\n<dt>Country</dt><dd>PE</dd>\n<dt>Current Weather</dt><dd>scattered clouds \n<dt>CMax Temp</dt><dd>61.93 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hilton Virginia Beach Oceanfront</dd>\n<dt>City</dt><dd>Virginia Beach</dd>\n<dt>Country</dt><dd>US</dd>\n<dt>Current Weather</dt><dd>clear sky \n<dt>CMax Temp</dt><dd>63.01 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd></dd>\n<dt>City</dt><dd>Dourbali</dd>\n<dt>Country</dt><dd>TD</dd>\n<dt>Current Weather</dt><dd>overcast clouds \n<dt>CMax Temp</dt><dd>74.79 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Pudong Holiday Hotel</dd>\n<dt>City</dt><dd>Aksu</dd>\n<dt>Country</dt><dd>CN</dd>\n<dt>Current Weather</dt><dd>overcast clouds \n<dt>CMax Temp</dt><dd>65.05 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Goto Guesthouse Utojuku & SA Car Rental</dd>\n<dt>City</dt><dd>Fukue</dd>\n<dt>Country</dt><dd>JP</dd>\n<dt>Current Weather</dt><dd>broken clouds \n<dt>CMax Temp</dt><dd>66.56 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Ночной клуб BasMax, Гостиница , Ресторан , Магазин-автозап. сто вулканизатор ,</dd>\n<dt>City</dt><dd>Kachiry</dd>\n<dt>Country</dt><dd>KZ</dd>\n<dt>Current Weather</dt><dd>overcast clouds \n<dt>CMax Temp</dt><dd>61.3 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd></dd>\n<dt>City</dt><dd>Elko</dd>\n<dt>Country</dt><dd>US</dd>\n<dt>Current Weather</dt><dd>clear sky \n<dt>CMax Temp</dt><dd>59.65 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Casa Laguna, Bed & Breakfast</dd>\n<dt>City</dt><dd>Guerrero Negro</dd>\n<dt>Country</dt><dd>MX</dd>\n<dt>Current Weather</dt><dd>clear sky \n<dt>CMax Temp</dt><dd>69.3 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Bonthe Holiday Village</dd>\n<dt>City</dt><dd>Bonthe</dd>\n<dt>Country</dt><dd>SL</dd>\n<dt>Current Weather</dt><dd>light rain \n<dt>CMax Temp</dt><dd>76.53 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Monte Mulini</dd>\n<dt>City</dt><dd>Rovinj</dd>\n<dt>Country</dt><dd>HR</dd>\n<dt>Current Weather</dt><dd>broken clouds \n<dt>CMax Temp</dt><dd>61.29 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Kamana</dd>\n<dt>City</dt><dd>Lima</dd>\n<dt>Country</dt><dd>PE</dd>\n<dt>Current Weather</dt><dd>broken clouds \n<dt>CMax Temp</dt><dd>58.89 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd></dd>\n<dt>City</dt><dd>Tucuma</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Current Weather</dt><dd>broken clouds \n<dt>CMax Temp</dt><dd>78.93 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Adriatico</dd>\n<dt>City</dt><dd>Tricase</dd>\n<dt>Country</dt><dd>IT</dd>\n<dt>Current Weather</dt><dd>broken clouds \n<dt>CMax Temp</dt><dd>64.31 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel novo Acre & Comercial Aguiar</dd>\n<dt>City</dt><dd>Eirunepe</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Current Weather</dt><dd>broken clouds \n<dt>CMax Temp</dt><dd>73.08 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Barravento Hotel</dd>\n<dt>City</dt><dd>Ilheus</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Current Weather</dt><dd>overcast clouds \n<dt>CMax Temp</dt><dd>72.32 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>LEANIF HOTEL RESTAURANT</dd>\n<dt>City</dt><dd>Kamina</dd>\n<dt>Country</dt><dd>CD</dd>\n<dt>Current Weather</dt><dd>few clouds \n<dt>CMax Temp</dt><dd>67.91 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd></dd>\n<dt>City</dt><dd>Bara</dd>\n<dt>Country</dt><dd>NG</dd>\n<dt>Current Weather</dt><dd>light rain \n<dt>CMax Temp</dt><dd>72.05 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Quality Inn Dubbo International</dd>\n<dt>City</dt><dd>Dubbo</dd>\n<dt>Country</dt><dd>AU</dd>\n<dt>Current Weather</dt><dd>light rain \n<dt>CMax Temp</dt><dd>60.93 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>DIAN SINKO</dd>\n<dt>City</dt><dd>Beyla</dd>\n<dt>Country</dt><dd>GN</dd>\n<dt>Current Weather</dt><dd>light rain \n<dt>CMax Temp</dt><dd>65.44 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Red Sea Resort & Suites Mandera County</dd>\n<dt>City</dt><dd>Mandera</dd>\n<dt>Country</dt><dd>KE</dd>\n<dt>Current Weather</dt><dd>light rain \n<dt>CMax Temp</dt><dd>78.58 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel La Ballena Azul</dd>\n<dt>City</dt><dd>Santa Marta</dd>\n<dt>Country</dt><dd>CO</dd>\n<dt>Current Weather</dt><dd>broken clouds \n<dt>CMax Temp</dt><dd>78.89 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>PTDC Motel Chitral</dd>\n<dt>City</dt><dd>Chitral</dd>\n<dt>Country</dt><dd>PK</dd>\n<dt>Current Weather</dt><dd>clear sky \n<dt>CMax Temp</dt><dd>65.07 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Ramada by Wyndham Moses Lake</dd>\n<dt>City</dt><dd>Moses Lake</dd>\n<dt>Country</dt><dd>US</dd>\n<dt>Current Weather</dt><dd>clear sky \n<dt>CMax Temp</dt><dd>72.28 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Comfort Suites Pflugerville - Austin North</dd>\n<dt>City</dt><dd>Pflugerville</dd>\n<dt>Country</dt><dd>US</dd>\n<dt>Current Weather</dt><dd>few clouds \n<dt>CMax Temp</dt><dd>77.59 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>HOTEL TERME DI RAPOLLA</dd>\n<dt>City</dt><dd>Melfi</dd>\n<dt>Country</dt><dd>IT</dd>\n<dt>Current Weather</dt><dd>overcast clouds \n<dt>CMax Temp</dt><dd>56.37 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Atlântico Rio Grande</dd>\n<dt>City</dt><dd>Rio Grande</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Current Weather</dt><dd>light rain \n<dt>CMax Temp</dt><dd>57.07 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd></dd>\n<dt>City</dt><dd>Mitu</dd>\n<dt>Country</dt><dd>CO</dd>\n<dt>Current Weather</dt><dd>broken clouds \n<dt>CMax Temp</dt><dd>75.33 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Floresta Amazonica Hotel</dd>\n<dt>City</dt><dd>Alta Floresta</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Current Weather</dt><dd>scattered clouds \n<dt>CMax Temp</dt><dd>75.29 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Kou-Bugny</dd>\n<dt>City</dt><dd>Vao</dd>\n<dt>Country</dt><dd>NC</dd>\n<dt>Current Weather</dt><dd>broken clouds \n<dt>CMax Temp</dt><dd>71.11 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Pinamar</dd>\n<dt>City</dt><dd>Zorritos</dd>\n<dt>Country</dt><dd>PE</dd>\n<dt>Current Weather</dt><dd>scattered clouds \n<dt>CMax Temp</dt><dd>69.21 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Apartment above Depot Bar</dd>\n<dt>City</dt><dd>Griffith</dd>\n<dt>Country</dt><dd>US</dd>\n<dt>Current Weather</dt><dd>overcast clouds \n<dt>CMax Temp</dt><dd>55.35 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>«ВатерЛоо» гостиница</dd>\n<dt>City</dt><dd>Gornoye Loo</dd>\n<dt>Country</dt><dd>RU</dd>\n<dt>Current Weather</dt><dd>clear sky \n<dt>CMax Temp</dt><dd>56.98 °F</dd>\n</dl>\n']

# %% [markdown]
# ## Use the provided code snippet to retrieve the latitude and longitude from each row and store them in a new DataFrame called `locations`.

# %%
# Get the latitude and longitude from each row and store in a new DataFrame.
locations = clean_hotel_df[["Lat", "Lng"]]

# Display sample data
locations.head(10)
# Out:
#         Lat       Lng
# 0    4.3750   -7.7169
# 1  -23.1203 -134.9692
# 3  -10.1256  -36.1756
# 5   27.8000   78.8500
# 6  -32.5000  137.7667
# 8  -33.6500  115.3333
# 9  -24.7911  -50.0119
# 10  -3.4320   10.6554
# 16 -22.9661  -42.0278
# 18  37.7167  -25.4333

# %% [markdown]
# ## Refactor your previous marker layer map code to create a marker layer map that will have pop-up markers for each city on the map.

# %%
# Add heatmap for the vacation spots and marker for each city.
max_temp = clean_hotel_df["Max Temp"]
current_weather = clean_hotel_df["Current Description"]
fig = gmaps.figure(center=(27.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp,dissipating=False,
             max_intensity=300, point_radius=4)
marker_layer = gmaps.marker_layer(locations, info_box_content = hotel_info)

# Call the figure to plot the data.
fig.add_layer(heat_layer)
#fig.add_layer(marker_layer)

# 11b. Display the figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
max_temp = clean_hotel_df["Max Temp"]
current_weather = clean_hotel_df["Current Description"]
fig = gmaps.figure(center=(27.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp,dissipating=False,
             max_intensity=300, point_radius=4)
marker_layer = gmaps.marker_layer(locations, info_box_content = hotel_info)

# Call the figure to plot the data.
fig.add_layer(marker_layer)
#fig.add_layer(marker_layer)

# 11b. Display the figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
